# %%
# Install Sweetviz and Kaggle API
# !pip install sweetviz
# !pip install kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 30.4 MB/s eta 0:00:00
# ...

# %%
# Create a Kaggle directory and move the API key
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download the New York City Airbnb dataset
# !kaggle datasets download -d dgomonov/new-york-city-airbnb-open-data

# Unzip the dataset
# !unzip new-york-city-airbnb-open-data.zip
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data
# License(s): CC0-1.0
# ...
#   0% 0.00/2.44M [00:00<?, ?B/s]
# 100% 2.44M/2.44M [00:00<00:00, 57.2MB/s]
# Archive:  new-york-city-airbnb-open-data.zip
#   inflating: AB_NYC_2019.csv
#   inflating: New_York_City_.png

# %%
# Import necessary libraries
import pandas as pd

# Load the Airbnb dataset
df = pd.read_csv('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Import Sweetviz library
import sweetviz as sv

# Generate a Sweetviz report for the Airbnb dataset
report = sv.analyze(df)

# Display the report in Colab
report.show_html('NYC_Airbnb_EDA.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report NYC_Airbnb_EDA.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from google.colab import files

# Download the generated Sweetviz report
files.download('NYC_Airbnb_EDA.html')
